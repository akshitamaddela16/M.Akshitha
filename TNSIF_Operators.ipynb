# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitamaddela16/M.Akshitha/blob/main/TNSIF_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
f=1.234
name="sai"
boo=True
print(a)
print(b)
print(f)
print(name)
print(boo)
print(type(a))
print(type(f))
print(type(name))
print(type(boo))
# Out:
# 10
# 20
# 1.234
# sai
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Task 1
# Artimatic operators
a = 10
b = 20
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
# Out:
# 30
# -10
# 200
# 0.5
# 10

# %%
# logical
a = True
b = False

print(a and b)
print(a or b)
print(not a)
print(not b)
# Out:
# False
# True
# False
# True

# %%
# Comparition
a = 10
b = 20

print("a == b :", a == b)
print("a != b :", a != b)
print("a > b :", a > b)
print("a < b :", a < b)
print("a >= b :", a >= b)
print("a <= b :", a <= b)
# Out:
# a == b : False
# a != b : True
# a > b : False
# a < b : True
# a >= b : False
# a <= b : True

# %%
# Assignment
a = 10

a += 5
print("a += 5 :", a)

a -= 3
print("a -= 3 :", a)

a *= 2
print("a *= 2 :", a)

a /= 4
print("a /= 4 :", a)

a %= 3
print("a %= 3 :", a)
# Out:
# a += 5 : 15
# a -= 3 : 12
# a *= 2 : 24
# a /= 4 : 6.0
# a %= 3 : 0.0
