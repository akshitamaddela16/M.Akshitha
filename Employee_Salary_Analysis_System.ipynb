# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitamaddela16/M.Akshitha/blob/main/Employee_Salary_Analysis_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5e721150-84e2-445f-9f1c-4211f8bae468" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e721150-84e2-445f-9f1c-4211f8bae468">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('employee_salary_dataset.csv')
df.head()
# Out:
#    EmployeeID        Name  Department  Experience_Years Education_Level  Age  \
# 0           1  Employee_1   Marketing                15          Master   53
# 1           2  Employee_2  Operations                 7        Bachelor   25
# 2           3  Employee_3          IT                12     High School   51
# 3           4  Employee_4  Operations                 8             PhD   44
# 4           5  Employee_5  Operations                15          Master   36
#
#    Gender       City  Monthly_Salary
# 0  Female      Delhi          111416
# 1  Female  Bangalore           95271
# 2  Female  Hyderabad           69064
# 3    Male      Delhi           95091
# 4  Female      Delhi          132450

# %%
import numpy as np

# %%
print("First 5 Rows")
print(df.head())

print("\nDataset Shape:")
print(df.shape)

print("\nColumns:")
print(df.columns)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# First 5 Rows
#    EmployeeID        Name  Department  Experience_Years Education_Level  Age  \
# 0           1  Employee_1   Marketing                15          Master   53
# 1           2  Employee_2  Operations                 7        Bachelor   25
# 2           3  Employee_3          IT                12     High School   51
# 3           4  Employee_4  Operations                 8             PhD   44
# 4           5  Employee_5  Operations                15          Master   36
#
#    Gender       City  Monthly_Salary
# 0  Female      Delhi          111416
# 1  Female  Bangalore           95271
# 2  Female  Hyderabad           69064
# 3    Male      Delhi           95091
# 4  Female      Delhi          132450
#
# Dataset Shape:
# (50, 9)
#
# Columns:
# Index(['EmployeeID', 'Name', 'Department', 'Experience_Years',
#        'Education_Level', 'Age', 'Gender', 'City', 'Monthly_Salary'],
#       dtype='object')
#
# Missing Values:
# EmployeeID          0
# Name                0
# ...

# %% [markdown]
# # 2. Handle Missing Values

# %%
df.fillna(df.select_dtypes(include=np.number).mean(), inplace=True)

# %% [markdown]
# # 3. Remove Duplicate Records

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Create Bonus Column

# %%
df["Bonus"] = df["Monthly_Salary"] * 0.10
print("Dataset after Bonus Column")
print(df.head())
# Out:
# Dataset after Bonus Column
#    EmployeeID        Name  Department  Experience_Years Education_Level  Age  \
# 0           1  Employee_1   Marketing                15          Master   53
# 1           2  Employee_2  Operations                 7        Bachelor   25
# 2           3  Employee_3          IT                12     High School   51
# 3           4  Employee_4  Operations                 8             PhD   44
# 4           5  Employee_5  Operations                15          Master   36
#
#    Gender       City  Monthly_Salary    Bonus  Total_Income
# 0  Female      Delhi          111416  11141.6      122557.6
# 1  Female  Bangalore           95271   9527.1      104798.1
# 2  Female  Hyderabad           69064   6906.4       75970.4
# 3    Male      Delhi           95091   9509.1      104600.1
# 4  Female      Delhi          132450  13245.0      145695.0

# %% [markdown]
# # 4. Create new  Column: Total Income

# %%
df["Total_Income"] = df["Monthly_Salary"] + df["Bonus"]

print("\nDataset after Bonus and Total Income")
print(df.head())
# Out:
# Dataset after Bonus and Total Income
#    EmployeeID        Name  Department  Experience_Years Education_Level  Age  \
# 0           1  Employee_1   Marketing                15          Master   53
# 1           2  Employee_2  Operations                 7        Bachelor   25
# 2           3  Employee_3          IT                12     High School   51
# 3           4  Employee_4  Operations                 8             PhD   44
# 4           5  Employee_5  Operations                15          Master   36
#
#    Gender       City  Monthly_Salary    Bonus  Total_Income
# 0  Female      Delhi          111416  11141.6      122557.6
# 1  Female  Bangalore           95271   9527.1      104798.1
# 2  Female  Hyderabad           69064   6906.4       75970.4
# 3    Male      Delhi           95091   9509.1      104600.1
# 4  Female      Delhi          132450  13245.0      145695.0

# %% [markdown]
# #5. Find employees earning above the average salary.

# %%
avg_salary = df["Monthly_Salary"].mean()

above_avg = df[df["Monthly_Salary"] > avg_salary]

print("\nAverage Salary =", avg_salary)

print("\nEmployees Earning Above Average Salary")
print(above_avg[["EmployeeID","Name","Department","Monthly_Salary"]])
# Out:
# Average Salary = 82288.8
#
# Employees Earning Above Average Salary
#     EmployeeID         Name  Department  Monthly_Salary
# 0            1   Employee_1   Marketing          111416
# 1            2   Employee_2  Operations           95271
# 3            4   Employee_4  Operations           95091
# 4            5   Employee_5  Operations          132450
# 10          11  Employee_11   Marketing          141381
# 11          12  Employee_12          IT          104909
# 14          15  Employee_15   Marketing           99290
# 15          16  Employee_16     Finance          101213
# 22          23  Employee_23   Marketing          122888
# 24          25  Employee_25          HR          132455
# 26          27  Employee_27          IT          119660
# 27          28  Employee_28     Finance          118179
# 29          30  Employee_30   Marketing           99543
# 32          33  Employee_33   Marketing          127946
# 33          34  Employee_34          HR          134616
# ...

# %% [markdown]
# #6. Find department-wise average salary.

# %%
dept_avg = df.groupby("Department")["Monthly_Salary"].mean()

print("\nDepartment-wise Average Salary")
print(dept_avg)
# Out:
# Department-wise Average Salary
# Department
# Finance       67261.900000
# HR            82945.142857
# IT            76520.500000
# Marketing     96430.846154
# Operations    84239.900000
# Name: Monthly_Salary, dtype: float64

# %% [markdown]
# #7. Apply NumPy functions (max, min, mean, std) on salaries.

# %%
salary_array = df["Monthly_Salary"].to_numpy()

print("\nSalary Statistics")
print("Maximum Salary :", np.max(salary_array))
print("Minimum Salary :", np.min(salary_array))
print("Mean Salary :", np.mean(salary_array))
print("Standard Deviation :", np.std(salary_array))
# Out:
# Salary Statistics
# Maximum Salary : 149123
# Minimum Salary : 28420
# Mean Salary : 82288.8
# Standard Deviation : 33184.53047550922

# %% [markdown]
# #8.Find the highest-paid employee.

# %%
highest_paid = df.loc[df["Monthly_Salary"].idxmax()]

print("\nHighest Paid Employee")
print(highest_paid)
# Out:
# Highest Paid Employee
# EmployeeID                   38
# Name                Employee_38
# Department           Operations
# Experience_Years              9
# Education_Level          Master
# Age                          23
# Gender                     Male
# City                     Mumbai
# Monthly_Salary           149123
# Bonus                   14912.3
# Total_Income           164035.3
# Name: 37, dtype: object

# %% [markdown]
# #9.Generate a summary report.

# %%
print("\n========== SUMMARY REPORT ==========")

print("Total Employees :", len(df))
print("Departments :", df["Department"].nunique())
print("Cities :", df["City"].nunique())

print("Average Salary :", round(avg_salary,2))
print("Highest Salary :", np.max(salary_array))
print("Lowest Salary :", np.min(salary_array))

print("Highest Paid Employee :", highest_paid["Name"])
print("Department :", highest_paid["Department"])

print("Average Experience :", round(df["Experience_Years"].mean(),2))
# Out:
# ========== SUMMARY REPORT ==========
# Total Employees : 50
# Departments : 5
# Cities : 5
# Average Salary : 82288.8
# Highest Salary : 149123
# Lowest Salary : 28420
# Highest Paid Employee : Employee_38
# Department : Operations
# Average Experience : 9.9
